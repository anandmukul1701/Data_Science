# %% [markdown]
# # Scatter Plot

# %%
import seaborn as sns
sns.set(style='white')

# Load the example mpg dataset
mpg = sns.load_dataset('mpg')
print(type(mpg))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# pretty print DataFrame
from tabulate import tabulate

print(tabulate(mpg, headers='keys',tablefmt='github'))
# Out:
# |     |   mpg |   cylinders |   displacement |   horsepower |   weight |   acceleration |   model_year | origin   | name                                 |
# |-----|-------|-------------|----------------|--------------|----------|----------------|--------------|----------|--------------------------------------|
# |   0 |  18   |           8 |          307   |          130 |     3504 |           12   |           70 | usa      | chevrolet chevelle malibu            |
# |   1 |  15   |           8 |          350   |          165 |     3693 |           11.5 |           70 | usa      | buick skylark 320                    |
# |   2 |  18   |           8 |          318   |          150 |     3436 |           11   |           70 | usa      | plymouth satellite                   |
# |   3 |  16   |           8 |          304   |          150 |     3433 |           12   |           70 | usa      | amc rebel sst                        |
# ...

# %%
# Plot mpg against horsepower

sns.scatterplot(x='horsepower', y='mpg', data=mpg)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
# Plot mpg against horsepower -- Adding grid
sns.set()

sns.scatterplot(x='horsepower', y='mpg', data=mpg)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
# Plot mpg against horsepower -- Adding grid
# Adding hue & title
sns.set()

sns.scatterplot(x='horsepower', y='mpg', data=mpg, hue='origin').set_title('ScatterPlot')
# Out:
# Text(0.5, 1.0, 'ScatterPlot')

# %%
# Plot mpg against horsepower -- Adding grid
# Adding hue & title
sns.set()

sns.scatterplot(x='horsepower', y='mpg', data=mpg, hue='origin',size='weight').set_title('ScatterPlot')
# Out:
# Text(0.5, 1.0, 'ScatterPlot')

# %%
sns.set()

sns.scatterplot(x='horsepower', y='mpg', data=mpg, hue='origin',size='weight', sizes=(10,200)).set_title('ScatterPlot')
# Out:
# Text(0.5, 1.0, 'ScatterPlot')

# %%
sns.set()

sns.scatterplot(x='horsepower', y='mpg', data=mpg, hue='origin',size='weight', sizes=(10,200), palette='muted').set_title('ScatterPlot')
# Out:
# Text(0.5, 1.0, 'ScatterPlot')

# %%
import matplotlib.pyplot as plt
sns.set()
plt.style.use('dark_background')
sns.scatterplot(x='horsepower', y='mpg', data=mpg, hue='origin',size='weight', sizes=(10,200), palette='muted').set_title('ScatterPlot')
# Out:
# Text(0.5, 1.0, 'ScatterPlot')

# %%
tips = sns.load_dataset('tips')

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(style='ticks', color_codes=True)

g = sns.FacetGrid(tips, col='time', row='smoker')
print(type(g))
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %%
import numpy as np

bins = np.arange(0,65,3)
#g = sns.FacetGrid(tips, col='time', row='smoker')
g.map(plt.hist, 'total_bill', bins=bins)

# %%
g = sns.FacetGrid(tips, col='time', row='smoker')
g.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

# %%
g = sns.FacetGrid(tips, col='time', hue='smoker')
(g.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')).add_legend()

# %%
bins = np.arange(0,65,3)
g = sns.FacetGrid(tips, col='day',height=4)
(g.map(plt.hist, 'total_bill', bins=bins)).add_legend()

# %%
bins = np.arange(0,65,3)
g = sns.FacetGrid(tips, col='day', row='smoker' ,height=4)
(g.map(plt.hist, 'total_bill', bins=bins)).add_legend()

# %%
att = sns.load_dataset('attention')

att.head()
# Out:
#    Unnamed: 0  subject attention  solutions  score
# 0           0        1   divided          1    2.0
# 1           1        2   divided          1    3.0
# 2           2        3   divided          1    3.0
# 3           3        4   divided          1    5.0
# 4           4        5   divided          1    4.0

# %%
g = sns.FacetGrid(att, col='subject', col_wrap=5 ,height=2)
(g.map(plt.plot, 'solutions', 'score', marker='.')).add_legend()

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(data=fmri, x='timepoint', y='signal')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
np.mean(fmri[fmri['timepoint']==5]['signal'])
# Out:
# 0.13772540199215538

# %%
sns.lineplot(data=fmri, x='timepoint', y='signal', hue='event')
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
ax = sns.lineplot(data=fmri, x='timepoint', y='signal', hue='region',style='event')

# %%
import pandas as pd

sns.set()

rs = np.random.RandomState(365)
values = rs.randn(365,2)
dates = pd.date_range('1 1 2016', periods=365, freq='D')
data = pd.DataFrame(values, dates, columns=['A', 'B'])

data.head()
# Out:
#                    A         B
# 2016-01-01  0.167921  0.523505
# 2016-01-02  0.817376  1.703846
# 2016-01-03 -2.146948  0.714199
# 2016-01-04 -0.760145  1.039422
# 2016-01-05 -0.966452 -0.143679

# %%
sns.lineplot(data=data, palette='tab10', linewidth=2.5)
# Out:
# <Axes: >

# %%
sns.set()
np.random.seed(10)
x = np.random.randn(100)
sns.displot(x)

# %%
sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(x, bw=0.2)
# Out:
# /var/folders/p_/fs2tb7r13c534frxmkk64z4w0000gn/T/ipykernel_1313/4080741456.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.2`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(x, bw=0.2)
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(x, bw=0.1)
# Out:
# /var/folders/p_/fs2tb7r13c534frxmkk64z4w0000gn/T/ipykernel_1313/4233141442.py:1: UserWarning:
#
# The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`.
# Setting `bw_method=0.1`, but please see the docs for the new parameters
# and update your code. This will become an error in seaborn v0.13.0.
#
#   sns.kdeplot(x, bw=0.1)
# <Axes: ylabel='Density'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x='total_bill', y='tip' , data=tips)

# %%
sns.jointplot(x='total_bill', y='tip' , data=tips, kind='kde')
