# %%
# !pip install bioinfokit
# Out:
# Collecting bioinfokit
#   Downloading bioinfokit-2.1.0.tar.gz (86 kB)
#      |████████████████████████████████| 86 kB 89 kB/s eta 0:00:011
# Requirement already satisfied: pandas in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from bioinfokit) (1.3.5)
# Requirement already satisfied: numpy in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from bioinfokit) (1.22.3)
# Requirement already satisfied: matplotlib in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from bioinfokit) (3.7.1)
# Requirement already satisfied: scipy in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from bioinfokit) (1.10.1)
# Requirement already satisfied: scikit-learn in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from bioinfokit) (1.0.2)
# Requirement already satisfied: seaborn in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from bioinfokit) (0.12.2)
# Collecting matplotlib-venn
#   Downloading matplotlib-venn-0.11.9.tar.gz (30 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp39-cp39-macosx_10_9_x86_64.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 211 kB/s eta 0:00:01
# Collecting textwrap3
#   Downloading textwrap3-0.9.2-py2.py3-none-any.whl (12 kB)
# Collecting adjustText
#   Downloading adjustText-0.8-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (4.39.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from matplotlib->bioinfokit) (3.0.4)
# Requirement already satisfied: zipp>=3.1.0 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->bioinfokit) (3.7.0)
# Requirement already satisfied: six>=1.5 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->bioinfokit) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from pandas->bioinfokit) (2021.3)
# Requirement already satisfied: joblib>=0.11 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from scikit-learn->bioinfokit) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages (from scikit-learn->bioinfokit) (2.2.0)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      |████████████████████████████████| 233 kB 199 kB/s eta 0:00:01
# Building wheels for collected packages: bioinfokit, matplotlib-venn
#   Building wheel for bioinfokit (setup.py) ... done
#   Created wheel for bioinfokit: filename=bioinfokit-2.1.0-py3-none-any.whl size=58665 sha256=0bd1f35b055d0da7f150519d3bb3d1f16f0e9f80e34326df98ac554ca38b5872
#   Stored in directory: /Users/anand/Library/Caches/pip/wheels/c9/ab/ed/8a7fde0a63653b75ac029d67598265d185e5915dfb594ddc59
#   Building wheel for matplotlib-venn (PEP 517) ... done
#   Created wheel for matplotlib-venn: filename=matplotlib_venn-0.11.9-py3-none-any.whl size=32999 sha256=21c59f375f090aeb63dfcb5d44a9db8bea88f425a02312f9e53d81526e66a0e9
#   Stored in directory: /Users/anand/Library/Caches/pip/wheels/25/de/d4/29dfc5d4520b956df7bc54a8464ad053042918bc525e88bf66
# Successfully built bioinfokit matplotlib-venn
# Installing collected packages: patsy, textwrap3, tabulate, statsmodels, matplotlib-venn, adjustText, bioinfokit
# Successfully installed adjustText-0.8 bioinfokit-2.1.0 matplotlib-venn-0.11.9 patsy-0.5.3 statsmodels-0.13.5 tabulate-0.9.0 textwrap3-0.9.2

# %%
import pandas as pd
from sklearn.manifold import TSNE
from bioinfokit.visuz import cluster

# %%
# load data
dataframe = pd.read_csv('TSNE_data.csv')
dataframe.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
# Split-out validation dataset
array = dataframe.values

# separate array into input and output components
X = array[:,1:]
Y = array[:,0]

# %%
# TSNE visualization
data_tsne = TSNE(n_components=2).fit_transform(X) 
cluster.tsneplot(score=data_tsne)
# Out:
# /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /Users/anand/opt/anaconda3/envs/analytics/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %%
color_class = dataframe['diagnosis'].to_numpy()
cluster.tsneplot(score=data_tsne,colorlist=color_class, legendpos='upper right')

# %%
data_tsne
# Out:
# array([[-28.192545 ,  -7.0484166],
#        [-30.53631  ,  -5.5855155],
#        [-27.709394 ,  -1.6633344],
#        ...,
#        [-14.677734 ,  11.771029 ],
#        [-29.151697 ,  -3.871857 ],
#        [ -2.5062616, -35.99455  ]], dtype=float32)
