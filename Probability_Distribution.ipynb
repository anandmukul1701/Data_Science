# %% [markdown]
# <a href="https://colab.research.google.com/github/anandmukul1701/ExcelR_DS/blob/main/Probability_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy import stats

# %% [markdown]
# ![Screenshot 2022-03-06 at 17.44.57.png](data:image/png;base64,...)

# %%
#stats.norm.cdf(x, loc = mean, scale = std )
stats.norm.cdf(70, loc = 60, scale = 10)
# Out:
# 0.8413447460685429

# %% [markdown]
# ![Screenshot 2022-03-06 at 17.48.48.png](data:image/png;base64,...)

# %%
stats.norm.cdf(680, loc = 711, scale = 29)
# Out:
# 0.14254260383881612

# %%
1 - stats.norm.cdf(720, loc = 711, scale = 29)
# Out:
# 0.37814937265194704

# %%
stats.norm.cdf(740, loc = 711, scale = 29) - stats.norm.cdf(680, loc = 711, scale = 29)
# Out:
# 0.6988021422297268
